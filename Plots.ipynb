# %%
import pandas as pd

file_path = "CleanedDataFrame.csv"

df = pd.read_csv(file_path)

# %%
job_title_value_counts = df['Job Title'].value_counts()
job_title_value_counts.plot.bar(color="Red", edgecolor="Black")
# Out:
# <Axes: xlabel='Job Title'>

# %%
df['Average Salary'].hist(bins=10, color="Blue", edgecolor="Black")
# Out:
# <Axes: >

# %%
df[df['Average Salary'] > 200]['Average Salary'].value_counts()
# Out:
# Average Salary
# 225.0    29
# 205.0    16
# 228.0     1
# 268.0     1
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(x="Rating", data=df, bins=10)

# %%
df.describe()
# Out:
#         Min Salary   Max Salary  Average Salary       Rating
# count  4226.000000  4226.000000     4226.000000  4226.000000
# mean     79.857075   132.939423      106.398249     3.830904
# std      31.413688    41.866541       35.620406     0.519318
# min      12.000000    44.000000       37.500000     1.500000
# 25%      55.000000   100.000000       78.000000     3.500000
# 50%      75.000000   129.000000      103.500000     3.900000
# 75%      99.000000   160.000000      130.000000     4.100000
# max     200.000000   386.000000      268.000000     5.000000

# %%
sns.displot(x="Average Salary", data=df, bins=10)

# %%
sns.countplot(x="Job Title", data=df)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'analyst'),
#   Text(1, 0, 'other'),
#   Text(2, 0, 'data scientist'),
#   Text(3, 0, 'machine learning engineer'),
#   Text(4, 0, 'researcher'),
#   Text(5, 0, 'data engineer'),
#   Text(6, 0, 'manager'),
#   Text(7, 0, 'deep learning engineer'),
#   Text(8, 0, 'director')])

# %%
sns.boxenplot(x="Rating", data=df)
# Out:
# <Axes: xlabel='Rating'>

# %%
df = df.sort_values(by='Average Salary', ascending=True)

# %%
df
# Out:
#            Job Title  Min Salary  Max Salary  Average Salary  Rating State
# 0            analyst          31          44            37.5     4.4    FL
# 1              other          26          49            37.5     3.7    OH
# 2            analyst          27          49            38.0     4.1    MI
# 3            analyst          27          49            38.0     3.8    IL
# 4            analyst          31          55            43.0     3.5    MI
# ...              ...         ...         ...             ...     ...   ...
# 4197           other         200         250           225.0     4.3    CA
# 4195  data scientist         200         250           225.0     4.4    CA
# 4209  data scientist         200         250           225.0     4.5    CA
# 4224  data scientist         170         286           228.0     3.8    NJ
# 4225           other         150         386           268.0     3.7    MI
#
# [4226 rows x 6 columns]

# %%
plt.barh(df['Job Title'], df['Average Salary'], color="skyBlue")
plt.xlabel('Average Salary')
plt.ylabel('Job Title')
plt.title('Average Salary by Job Title')
plt.grid(axis='y')
plt.show()

# %%
df[df['Job Title'] == "director"]
# Out:
#      Job Title  Min Salary  Max Salary  Average Salary  Rating State
# 569   director          46          83            64.5     3.6    PA
# 783   director          49          92            70.5     3.6    TX
# 1785  director          71         122            96.5     3.8    CA
# 2888  director          81         165           123.0     3.5    MI
# 2940  director         110         139           124.5     4.0    NY
# 3202  director          94         166           130.0     3.6    PA
# 3489  director         110         169           139.5     3.1    CA
# 3578  director         111         175           143.0     3.6    CA
# 3587  director         101         187           144.0     4.1    NJ
# 3702  director         103         192           147.5     4.1    NJ

# %%
plt.bar(df['State'], df['Average Salary'])
plt.xlabel('State')
plt.ylabel('Average Salary')
plt.title('Average Salary by State')
plt.grid(axis='x')
plt.xticks(rotation=45)
plt.show()

# %%
states = ['CA', 'NY', 'TX']
selected_states = df.loc[df['State'].isin(states)]
selected_states
# Out:
#            Job Title  Min Salary  Max Salary  Average Salary  Rating State
# 90           analyst          38          68            53.0     3.7    TX
# 91    data scientist          38          68            53.0     3.7    TX
# 93     data engineer          34          72            53.0     3.7    CA
# 94     data engineer          34          72            53.0     3.9    CA
# 96     data engineer          34          72            53.0     2.4    CA
# ...              ...         ...         ...             ...     ...   ...
# 4199  data scientist         200         250           225.0     3.9    CA
# 4198  data scientist         200         250           225.0     4.1    CA
# 4197           other         200         250           225.0     4.3    CA
# 4195  data scientist         200         250           225.0     4.4    CA
# 4209  data scientist         200         250           225.0     4.5    CA
#
# [2111 rows x 6 columns]

# %%
sns.scatterplot(x='Rating', y='Average Salary', data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Average Salary'>

# %%
sns.scatterplot(x='Rating', y='Average Salary', data=df, hue='Job Title')
# Out:
# <Axes: xlabel='Rating', ylabel='Average Salary'>

# %%
managers = df[df['Job Title'] == 'manager']
managers
# Out:
#      Job Title  Min Salary  Max Salary  Average Salary  Rating State
# 45     manager          38          59            48.5     3.9    IL
# 49     manager          31          66            48.5     3.9    NJ
# 43     manager          38          59            48.5     3.8    IL
# 80     manager          34          72            53.0     4.0    CA
# 114    manager          41          66            53.5     4.3    TX
# 141    manager          39          69            54.0     4.2    CA
# 187    manager          37          75            56.0     2.8    CA
# 212    manager          40          73            56.5     4.5    IL
# 211    manager          40          73            56.5     2.6    IL
# 298    manager          47          73            60.0     4.1    AZ
# 263    manager          47          73            60.0     3.6    AZ
# 375    manager          44          80            62.0     3.8    PA
# 402    manager          39          86            62.5     3.9    OH
# 504    manager          45          81            63.0     3.7    AZ
# 565    manager          47          82            64.5     3.7    IL
# 784    manager          49          92            70.5     3.1    TX
# 804    manager          54          88            71.0     3.2    FL
# 863    manager          48          98            73.0     2.8    TX
# 941    manager          48         100            74.0     3.7    MA
# 971    manager          46         104            75.0     3.6    AZ
# 1006   manager          57          94            75.5     3.8    OH
# 989    manager          45         106            75.5     4.0    PA
# 1114   manager          50         110            80.0     4.1    TX
# 1142   manager          64          97            80.5     3.7    AZ
# 1201   manager          60         105            82.5     4.6    IL
# 1255   manager          57         110            83.5     4.3    FL
# 1332   manager          72          97            84.5     3.7    TX
# 1377   manager          57         114            85.5     3.8    MA
# 1465   manager          73         102            87.5     3.3    TX
# 1464   manager          73         102            87.5     3.9    TX
# 1614   manager          60         124            92.0     4.1    CA
# 1826   manager          70         123            96.5     3.4    IL
# 1846   manager          73         122            97.5     3.9    MI
# 2035   manager          76         125           100.5     4.5    CA
# 2100   manager          72         134           103.0     1.9    CA
# 2171   manager          73         136           104.5     4.2    TX
# 2321   manager          96         119           107.5     4.9    NY
# 2404   manager          80         140           110.0     4.1    MA
# 2556   manager          73         154           113.5     4.0    VA
# 2658   manager          92         144           118.0     3.9    AZ
# 2644   manager          92         144           118.0     3.2    AZ
# 2809   manager          85         159           122.0     2.4    TX
# 3114   manager         114         144           129.0     3.6    TX
# 3081   manager          98         160           129.0     3.9    OH
# 3263   manager          86         178           132.0     4.1    CA
# 3364   manager         119         147           133.0     4.0    NY
# 3402   manager         100         172           136.0     3.1    TX
# 3557   manager         111         175           143.0     4.8    CA
# 3729   manager         113         184           148.5     3.8    CA
# 3764   manager         136         164           150.0     2.4    CA
# 3760   manager         136         164           150.0     3.6    CA
# 3759   manager         136         164           150.0     3.5    CA
# 3954   manager         114         211           162.5     3.4    CA
# 4078   manager         134         218           176.0     3.1    CA
# 4070   manager         134         218           176.0     4.5    CA
# 4069   manager         134         218           176.0     4.5    CA
# 4103   manager         138         217           177.5     3.2    TX
# 4095   manager         138         217           177.5     2.0    TX
# 4137   manager         143         237           190.0     3.6    PA
# 4219   manager         200         250           225.0     3.4    CA

# %%
sns.scatterplot(x='Rating', y='Average Salary', data=managers)
# Out:
# <Axes: xlabel='Rating', ylabel='Average Salary'>
